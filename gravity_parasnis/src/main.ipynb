# %%
'''

This code aims for density calculation using Parasnis Method

by:
arif.darmawan@riflab.com
9 February 2023

'''
# Out:
# '\n\nThis code aims for density calculation using Parasnis Method\n\nby:\narif.darmawan@riflab.com\n9 February 2023\n\n'

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
import numpy as np

# %%
data_file = '../../../data/data_gravity/1997_data.xlsx'
df = pd.read_excel(data_file, sheet_name='data1', header=0, na_values=None)

# %%
X = (0.04192 * df['Z']) - df['TC_1.00']
Y = df['FAA']

# %%
coef = np.polyfit(X, Y, 1)
poly1d_fn = np.poly1d(coef)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(X, Y, color='black', linestyle='None', marker='o', markersize=2, alpha=1)
ax.plot(X, poly1d_fn(X), '-', label=f'$y = {coef[0]:.1f}x {coef[1]:+.1f}$')

ax.set_title('Parasnis Chart')
ax.set_xlabel('(0.04192 * h) - TC')
ax.set_ylabel('FAA')

# ax.set_xlim([60, 100])
# ax.set_ylim([260, 380])
ax.legend()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X = np.array(X)
Y = np.array(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X.reshape(-1, 1), Y, test_size=0.33, random_state=42)

print(len(X), len(X_test), len(X_train), X_train)
lr_clf = LogisticRegression(random_state=0).fit(X_train, Y_train)
# lr_clf.score(X_test, Y_test)

# fig, ax = plt.subplots(figsize=(10, 5))
# ax.scatter()
# Out:
# 494 164 330 [[63.15307365]
#  [79.87614255]
#  [58.40636979]
#  [82.17417267]
#  [51.15304165]
#  [72.17685318]
#  [78.3901878 ]
#  [79.72232227]
#  [85.9590708 ]
#  [74.10070161]
#  [48.81281579]
#  [60.14669562]
#  [61.29567198]
#  [82.92014639]
#  [80.62184226]
#  [62.14657928]
#  [78.3292326 ]
#  [52.20576264]
#  [74.01577435]
#  [83.2110605 ]
#  [80.57791397]
#  [53.74278041]
#  [67.47015667]
#  [69.25443648]
#  [83.45945461]
#  [67.0090416 ]
#  [75.26367643]
#  [74.7516911 ]
#  [75.27337716]
#  [52.82427154]
#  [58.73838247]
#  [69.04594479]
#  [64.54817239]
#  [80.61836613]
#  [79.05372103]
#  [78.51831248]
#  [65.46935448]
#  [70.35299132]
#  [46.50582379]
#  [51.30624098]
#  [74.60918912]
#  [62.07548983]
#  [72.0554411 ]
#  [77.56755205]
#  [58.76868891]
#  [61.97032408]
#  [72.82112479]
#  [79.51412848]
#  [86.37191571]
#  [61.03380014]
#  [76.18786584]
#  [58.23256866]
#  [78.76027528]
#  [75.52173575]
#  [67.33530626]
#  [62.42820891]
#  [77.00696796]
#  [76.92191501]
#  [60.94723599]
#  [91.08130189]
#  [69.06812881]
#  [65.65888031]
#  [77.22009396]
#  [65.61165767]
#  [64.99267939]
#  [59.22751285]
#  [79.31629031]
#  [74.07333859]
#  [90.43349284]
#  [67.45785913]
#  [77.0536706 ]
#  [70.5676498 ]
#  [62.33500516]
#  [68.48892423]
#  [67.88562286]
#  [68.5901451 ]
#  [56.57738401]
#  [69.87098749]
#  [76.51505416]
#  [51.03159293]
#  [54.19054151]
#  [72.47523979]
#  [86.08051093]
#  [69.75716731]
#  [74.71436835]
#  [56.71787721]
#  [69.4282124 ]
#  [54.18903966]
#  [52.01196837]
#  [80.04025428]
#  [86.99162978]
#  [75.8796622 ]
#  [71.73344445]
#  [68.30132302]
#  [73.13504527]
#  [80.94998417]
#  [67.5142572 ]
#  [62.18565957]
#  [74.74013777]
#  [63.42144812]
#  [67.68158478]
#  [69.78859162]
#  [60.62812961]
#  [60.05682194]
#  [72.82929229]
#  [68.70907172]
#  [66.8048169 ]
#  [86.00113293]
#  [58.5412233 ]
#  [76.79614493]
#  [46.51772755]
#  [76.48028014]
#  [63.08044382]
#  [70.20399295]
#  [61.73023341]
#  [75.80253057]
#  [81.4155378 ]
#  [73.50116633]
#  [58.78882009]
#  [74.54579357]
#  [85.55240641]
#  [68.85711105]
#  [72.21353173]
#  [77.96426349]
#  [67.74191469]
#  [56.50378672]
#  [83.09117712]
#  [72.36399   ]
#  [84.99907698]
#  [59.24377882]
#  [86.08528295]
#  [64.58673717]
#  [47.954043  ]
#  [67.02113645]
#  [71.25536643]
#  [73.3180323 ]
#  [41.25265824]
#  [81.27545466]
#  [72.6289618 ]
#  [83.14564961]
#  [68.39951381]
#  [61.53818456]
#  [72.29383425]
#  [68.78152552]
#  [71.84529842]
#  [76.58586715]
#  [71.34568917]
#  [70.13172692]
#  [55.30257855]
#  [74.39583883]
#  [69.01414909]
#  [64.49755788]
#  [62.91582694]
#  [77.95738197]
#  [74.86630121]
#  [62.83868299]
#  [66.41839137]
#  [65.90715352]
#  [72.75818832]
#  [68.54695063]
#  [80.81441544]
#  [76.06297277]
#  [44.28645607]
#  [71.37484955]
#  [57.54960912]
#  [78.86458928]
#  [62.95400143]
#  [72.55220972]
#  [60.4009849 ]
#  [53.2677152 ]
#  [75.65923269]
#  [72.07098766]
#  [70.37304287]
#  [77.90968799]
#  [78.84275505]
#  [75.16926544]
#  [75.44583162]
#  [65.7792112 ]
#  [61.53704994]
#  [68.48722995]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 10
#       7 X_train, X_test, Y_train, Y_test = train_test_split(X.reshape(-1, 1), Y, test_size=0.33, random_state=42)
#       9 print(len(X), len(X_test), len(X_train), X_train)
# ---> 10 lr_clf = LogisticRegression(random_state=0).fit(X_train, Y_train)
#
# File c:\Users\Geodipa\miniconda3\lib\site-packages\sklearn\linear_model\_logistic.py:1204, in LogisticRegression.fit(self, X, y, sample_weight)
#    1194     _dtype = [np.float64, np.float32]
#    1196 X, y = self._validate_data(
#    1197     X,
#    1198     y,
#    (...)
#    1202     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1203 )
# -> 1204 check_classification_targets(y)
#    1205 self.classes_ = np.unique(y)
#    1207 multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#
# File c:\Users\Geodipa\miniconda3\lib\site-packages\sklearn\utils\multiclass.py:207, in check_classification_targets(y)
#     199 y_type = type_of_target(y, input_name="y")
#     200 if y_type not in [
#     201     "binary",
#     202     "multiclass",
#    (...)
#     205     "multilabel-sequences",
#     206 ]:
# --> 207     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'

# %%
X_train
# Out:
# 447    63.153074
# 108    79.876143
# 37     58.406370
# 157    82.174173
# 460    51.153042
#          ...
# 106    75.169265
# 270    75.445832
# 348    65.779211
# 435    61.537050
# 102    68.487230
# Length: 330, dtype: float64
